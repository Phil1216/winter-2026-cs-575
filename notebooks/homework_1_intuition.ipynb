# %%
from plotting_utilities import show_graph, show_degree_distribution
import networkx as nx
import plotting_utilities as pu

# %% [markdown]
# Problem 11

# %%
G = nx.complete_graph(8)

show_graph(G)
show_degree_distribution(G)

# %% [markdown]
# Problem 12

# %%
G = nx.circulant_graph(8,[1])

show_graph(G)
show_degree_distribution(G)

# %% [markdown]
# Problem 13

# %%
G = nx.circulant_graph(8,[1,2])

show_graph(G)
show_degree_distribution(G)

# %% [markdown]
# Problem 14

# %%
G = nx.barbell_graph(3,2)

show_graph(G)
show_degree_distribution(G)
